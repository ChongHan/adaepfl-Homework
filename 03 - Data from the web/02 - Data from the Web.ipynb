# %% [markdown]
# **Homework 02 - Data from the Web**

# %%
# Import libraries
import pandas as pd
import numpy as np

from bs4 import BeautifulSoup
import requests

# %%
# URL of IS Academia public access form
ISA_form_url = 'http://isa.epfl.ch/imoniteur_ISAP/!GEDPUBLICREPORTS.filter?ww_i_reportModel=133685247'

# Some variable used
QUERY_STRING = 'query_string'
EMPTY_DATA_STRING = "**NO_DATA**"

# %% [markdown]
# **Retrieve data: how to**
#
# In order to get the data, we need to perform a web crowl on the IS-Academia public plateform. IS-Academia has an online webpage with a form allowing us to download data based on different criteria (e.g. year, semester, ...)
#
# In order to have a convienient way to retrieve data from this form, we create a data structure with all possibilities the form accepted for its filter. The data structure we decided to use is a dictionary:
#
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Filter name  -> <br/>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Filter value -> Filter value id <br/>
#
# As you can see, the dictionary is actually a dictionary of dictionaries. The first level correponds to the filter name. The second level is all filter values possibles associated with the id.
#
# Exemple:<br/>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Unité académique  -> <br/>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Informatique -> 249847 <br/>
#
# Note that the second level will also contain the string to use when creating the query.

# %%
# Construction of the form "values -> id" dictionary

# Retrieve HTML page
r  = requests.get(ISA_form_url)
soup = BeautifulSoup(r.text, 'html.parser')

# Filter HTML page to get only the filters
table = soup.find(lambda tag: tag.name == 'table' and tag['id'] == 'filtre')

# Each filter name has its own 'tr'
filter_names = table.findAll('tr')

# The dictionnary to store form "values -> id"
formValues= {}

for filter_name in filter_names:
    # Second level of the dictionary
    dic = {}
    
    # String correspind to the filter name (first level)
    filter_name_string = filter_name.find('th').string
    
    
    # The first entry on the second level is the string to use for the query
    dic[QUERY_STRING] = filter_name.find('select')['name']
    
    
    # Now we iterate over each possibility for this filter
    filter_values = filter_name.findAll(lambda tag: tag.name == 'option' and tag['value'] != "null")
    for v in filter_values:
        # Add each combination of "filter value -> id" to the second level
        dic[v.string] = v['value']
    
    # Add the first level to the dictionary
    formValues[filter_name_string] = dic

formValues
# Out:
# {'Période académique': {'2007-2008': '978181',
#   '2008-2009': '978187',
#   '2009-2010': '978195',
#   '2010-2011': '39486325',
#   '2011-2012': '123455150',
#   '2012-2013': '123456101',
#   '2013-2014': '213637754',
#   '2014-2015': '213637922',
#   '2015-2016': '213638028',
#   '2016-2017': '355925344',
#   'query_string': 'ww_x_PERIODE_ACAD'},
#  'Période pédagogique': {'Bachelor semestre 1': '249108',
#   'Bachelor semestre 2': '249114',
#   'Bachelor semestre 3': '942155',
#   'Bachelor semestre 4': '942163',
#   'Bachelor semestre 5': '942120',
#   'Bachelor semestre 5b': '2226768',
#   'Bachelor semestre 6': '942175',
#   'Bachelor semestre 6b': '2226785',
#   'Master semestre 1': '2230106',
#   'Master semestre 2': '942192',
#   'Master semestre 3': '2230128',
#   'Master semestre 4': '2230140',
#   'Mineur semestre 1': '2335667',
#   'Mineur semestre 2': '2335676',
#   'Mise à niveau': '2063602308',
#   'Projet Master automne': '249127',
#   'Projet Master printemps': '3781783',
#   'Semestre automne': '953159',
#   'Semestre printemps': '2754553',
#   'Stage automne 3ème année': '953137',
#   'Stage automne 4ème année': '2226616',
#   'Stage printemps 3ème année': '983606',
#   'Stage printemps 4ème année': '2226626',
#   'Stage printemps master': '2227132',
#   'query_string': 'ww_x_PERIODE_PEDAGO'},
#  'Type de semestre': {"Semestre d'automne": '2936286',
#   'Semestre de printemps': '2936295',
#   'query_string': 'ww_x_HIVERETE'},
#  'Unité académique': {'Architecture': '942293',
#   'Chimie et génie chimique': '246696',
#   'Cours de mathématiques spéciales': '943282',
#   'EME (EPFL Middle East)': '637841336',
#   'Génie civil': '942623',
#   'Génie mécanique': '944263',
#   'Génie électrique et électronique ': '943936',
#   'Humanités digitales': '2054839157',
#   'Informatique': '249847',
#   'Ingénierie financière': '120623110',
#   'Management de la technologie': '946882',
#   'Mathématiques': '944590',
#   'Microtechnique': '945244',
#   'Physique': '945571',
#   'Science et génie des matériaux': '944917',
#   "Sciences et ingénierie de l'environnement": '942953',
#   'Sciences et technologies du vivant': '945901',
#   'Section FCUE': '1574548993',
#   'Systèmes de communication': '946228',
#   'query_string': 'ww_x_UNITE_ACAD'}}

# %% [markdown]
# **Retrieve data: build queries**
#
# We made a function in order to create in an easy and intuitive way a query URL. The function uses the dictionary build before to retrive the strings and id to use inside the URL.

# %%
def build_query_url(section, year, semester, season=EMPTY_DATA_STRING):
    """ Create an query URL for IS-Academia. The webpage will contain all data about EPFL student
        register for a semester in a specifc year in a section. The section, year, and semester are 
        provided as function arguments.
        Note that the function can also support the season semester (Spring or Autumn), but its 
        optional (not needed for the homework)"""
    
    # CONSTANTS TO USE IN THE URL
    url = ISA_url + '?'
    url += 'ww_x_GPS=-1&'
    url += 'ww_i_reportModel=133685247&'
    url += 'ww_i_reportModelXsl=133685270&'
    
    # Add the section (e.g. Informatique)
    v1 = formValues['Unité académique']
    url += v1[QUERY_STRING]+'='+v1[section]+'&'
    
    # Add the year (e.g. 2016-2017)
    v1 = formValues['Période académique']
    url += v1[QUERY_STRING]+'='+v1[year]+'&'
    
    # Add the semester (e.g. Bachelor semester 5)
    v1 = formValues['Période pédagogique']
    url += v1[QUERY_STRING]+'='+v1[semester]
    
    # If a season is specified, add it to the query
    if (season != EMPTY_DATA_STRING):
        v1 = formValues['Type de semestre']
        url += '&'+v1[QUERY_STRING]+'='+v1[season]
    
    
    return url

# %% [markdown]
# **Retrieve data. From HTML to Dataframe**
# Once we have a query URL to make our request, we need to extract the data stored in an HTML table into a Pandas Dataframe.

# %%
url = build_query_url('Informatique', '2016-2017', 'Bachelor semestre 5')

r  = requests.get(url)
soup = BeautifulSoup(r.text, 'html.parser')

# Dataframe structure
header = []        # Will store the header for each column
content = []       # The content of the data, row by row

#Student data is stored in the only 'table' in the HTML
for table in soup.find_all('table'):    
    
    #***************HEADER***********
    # The header is bold in the html page, in a 'th'
    for column_header in table.find_all('th'):
        # Only happend the header is it's not empty 
        # This is also a way to clean the 'th' string we receive from the html table, 
        # because the first 'th' is not a column header
        if column_header.string:    
            header.append(column_header.string)
                
                
    #***************CONTENT***********
    # The actual content of the table, the rows
    # Each row represents a student
    for students in table.find_all('tr'):
        
        student_row=[]
        #Each column attribute for a student is stored in a 'td'
        for student_column in students.find_all('td'):    
            s = student_column.string
            # If there is no data for a specific row, replace it by the 'empty_data' variable
            if (not s):
                student_row.append(EMPTY_DATA_STRING)
            else:
                student_row.append(s)
                
        if student_row:
            # In the HTML table retrieve from ISAcademia, there is a last 'td' in
            # the HTML table which doesn't correspond to any column. Need to remove it
            student_row.pop()
            content.append(student_row)

# Create a DataFrame from the data recovered.
df = pd.DataFrame(content, columns=header)
df
# Out:
#      Civilité                                    Nom Prénom  \
# 0    Monsieur                            Abate Bryan Jeremy
# 1    Monsieur                             Alami-Idrissi Ali
# 2    Monsieur                               Albergoni Tobia
# 3    Monsieur                      Alonso Seisdedos Florian
# 4    Monsieur                                 Aoun Leonardo
# 5    Monsieur                      Bachmann Roman Christian
# 6    Monsieur                       Badoux Christophe Dylan
# 7    Monsieur                Ballerini Marco Roberto Julian
# 8      Madame                                  Baraschi Zoé
# 9    Monsieur                           Bardet Mike Douglas
# 10   Monsieur                                Barman Raphaël
# 11   Monsieur                            Bazzucchi Vincenzo
# 12   Monsieur                          Beck Johannes Magnus
# 13   Monsieur                                  Benlalah Ali
# 14   Monsieur                                   Bickel Marc
# 15   Monsieur                  Boissaye Arnaud Didier Marie
# 16   Monsieur                            Bouvet Quentin Luc
# 17   Monsieur                      Bovel Matthieu Alexandre
# 18   Monsieur                                  Branca Colin
# 19   Monsieur                    Breitenstein Yannick Lucas
# 20   Monsieur                                   Bucev Mario
# 21   Monsieur              Burgelin Clément Louis Alexandre
# 22   Monsieur                         Caforio Andrea Felice
# 23   Monsieur                        Cavaleri Alexandre Guy
# 24   Monsieur                         Cloux Olivier Jérémie
# 25   Monsieur                              Collaud Jonathan
# 26   Monsieur              Combes Amaury Christian François
# 27   Monsieur               Conti Riccardo Ambrogio Nikolai
# 28   Monsieur                          Coudert Rémi Edouard
# 29   Monsieur                                Courtois Jules
# ..        ...                                           ...
# 89   Monsieur                         Pinedo Camacho Alvaro
# 90   Monsieur                           Pisa Maxime Quentin
# 91   Monsieur            Pizarro Solar Rafael Ulises Luzius
# 92   Monsieur                       Pleskowicz Michal Piotr
# 93   Monsieur                                  Poma Florian
# 94   Monsieur                                 Ramirez Lucas
# 95     Madame                            Reiss Saskia Naomi
# 96   Monsieur                                   Resin David
# 97   Monsieur                             Rey Samuel Pierre
# 98     Madame  Richard Lou Fortunée Valentine Yvonne Émilie
# 99   Monsieur                        Rigori Valentin Joseph
# 100  Monsieur         Rinaldi Vincent Michel Arnold Patrick
# 101  Monsieur                         Roduit Dominique Jean
# 102  Monsieur                       Romerio Lucio Ezechiele
# 103  Monsieur                Rossier Louis Dominique Joseph
# 104  Monsieur                         Sánchez Keller Aleixo
# 105  Monsieur                               Scanzi Jonathan
# 106  Monsieur                                  Schürch Loïc
# 107  Monsieur                      Selim Stephan Sameh Saad
# 108  Monsieur                                    Soufi Raja
# 109  Monsieur            Stalder Nicodème Josèphe Maria Pio
# 110  Monsieur                                Treyer Thierry
# 111  Monsieur                         Vaucher Timoté Pascal
# 112  Monsieur                                Viaccoz Cédric
# 113  Monsieur                                Weier Philippe
# 114  Monsieur                                   Wicht Bruno
# 115  Monsieur                               Willemin Xavier
# 116  Monsieur                          Wütschert Robin Axel
# 117  Monsieur                          Zbinden Boris Adrien
# 118  Monsieur                         Zenhäusern Joey Kevin
#
#     Orientation Bachelor Orientation Master Spécialisation  \
# 0            **NO_DATA**        **NO_DATA**    **NO_DATA**
# 1            **NO_DATA**        **NO_DATA**    **NO_DATA**
# 2            **NO_DATA**        **NO_DATA**    **NO_DATA**
# 3            **NO_DATA**        **NO_DATA**    **NO_DATA**
# 4            **NO_DATA**        **NO_DATA**    **NO_DATA**
# 5            **NO_DATA**        **NO_DATA**    **NO_DATA**
# 6            **NO_DATA**        **NO_DATA**    **NO_DATA**
# 7            **NO_DATA**        **NO_DATA**    **NO_DATA**
# 8            **NO_DATA**        **NO_DATA**    **NO_DATA**
# 9            **NO_DATA**        **NO_DATA**    **NO_DATA**
# 10           **NO_DATA**        **NO_DATA**    **NO_DATA**
# 11           **NO_DATA**        **NO_DATA**    **NO_DATA**
# 12           **NO_DATA**        **NO_DATA**    **NO_DATA**
# 13           **NO_DATA**        **NO_DATA**    **NO_DATA**
# 14           **NO_DATA**        **NO_DATA**    **NO_DATA**
# 15           **NO_DATA**        **NO_DATA**    **NO_DATA**
# 16           **NO_DATA**        **NO_DATA**    **NO_DATA**
# 17           **NO_DATA**        **NO_DATA**    **NO_DATA**
# 18           **NO_DATA**        **NO_DATA**    **NO_DATA**
# 19           **NO_DATA**        **NO_DATA**    **NO_DATA**
# 20           **NO_DATA**        **NO_DATA**    **NO_DATA**
# 21           **NO_DATA**        **NO_DATA**    **NO_DATA**
# 22           **NO_DATA**        **NO_DATA**    **NO_DATA**
# 23           **NO_DATA**        **NO_DATA**    **NO_DATA**
# 24           **NO_DATA**        **NO_DATA**    **NO_DATA**
# 25           **NO_DATA**        **NO_DATA**    **NO_DATA**
# 26           **NO_DATA**        **NO_DATA**    **NO_DATA**
# 27           **NO_DATA**        **NO_DATA**    **NO_DATA**
# 28           **NO_DATA**        **NO_DATA**    **NO_DATA**
# 29           **NO_DATA**        **NO_DATA**    **NO_DATA**
# ..                   ...                ...            ...
# 89           **NO_DATA**        **NO_DATA**    **NO_DATA**
# 90           **NO_DATA**        **NO_DATA**    **NO_DATA**
# 91           **NO_DATA**        **NO_DATA**    **NO_DATA**
# 92           **NO_DATA**        **NO_DATA**    **NO_DATA**
# 93           **NO_DATA**        **NO_DATA**    **NO_DATA**
# 94           **NO_DATA**        **NO_DATA**    **NO_DATA**
# 95           **NO_DATA**        **NO_DATA**    **NO_DATA**
# 96           **NO_DATA**        **NO_DATA**    **NO_DATA**
# 97           **NO_DATA**        **NO_DATA**    **NO_DATA**
# 98           **NO_DATA**        **NO_DATA**    **NO_DATA**
# 99           **NO_DATA**        **NO_DATA**    **NO_DATA**
# 100          **NO_DATA**        **NO_DATA**    **NO_DATA**
# 101          **NO_DATA**        **NO_DATA**    **NO_DATA**
# 102          **NO_DATA**        **NO_DATA**    **NO_DATA**
# 103          **NO_DATA**        **NO_DATA**    **NO_DATA**
# 104          **NO_DATA**        **NO_DATA**    **NO_DATA**
# 105          **NO_DATA**        **NO_DATA**    **NO_DATA**
# 106          **NO_DATA**        **NO_DATA**    **NO_DATA**
# 107          **NO_DATA**        **NO_DATA**    **NO_DATA**
# 108          **NO_DATA**        **NO_DATA**    **NO_DATA**
# 109          **NO_DATA**        **NO_DATA**    **NO_DATA**
# 110          **NO_DATA**        **NO_DATA**    **NO_DATA**
# 111          **NO_DATA**        **NO_DATA**    **NO_DATA**
# 112          **NO_DATA**        **NO_DATA**    **NO_DATA**
# 113          **NO_DATA**        **NO_DATA**    **NO_DATA**
# 114          **NO_DATA**        **NO_DATA**    **NO_DATA**
# 115          **NO_DATA**        **NO_DATA**    **NO_DATA**
# 116          **NO_DATA**        **NO_DATA**    **NO_DATA**
# 117          **NO_DATA**        **NO_DATA**    **NO_DATA**
# 118          **NO_DATA**        **NO_DATA**    **NO_DATA**
#
#                         Filière opt.       Mineur   Statut  \
# 0               6 - Visual computing  **NO_DATA**    Congé
# 1    5 - Signal and Image Processing  **NO_DATA**    Congé
# 2               6 - Visual computing  **NO_DATA**  Présent
# 3                        **NO_DATA**  **NO_DATA**    Congé
# 4               6 - Visual computing  **NO_DATA**    Congé
# 5               6 - Visual computing  **NO_DATA**    Congé
# 6               6 - Visual computing  **NO_DATA**  Présent
# 7               6 - Visual computing  **NO_DATA**  Présent
# 8               6 - Visual computing  **NO_DATA**  Présent
# 9               6 - Visual computing  **NO_DATA**  Présent
# 10   4 - Networks and Communications  **NO_DATA**  Présent
# 11              6 - Visual computing  **NO_DATA**  Présent
# 12              6 - Visual computing  **NO_DATA**    Congé
# 13   5 - Signal and Image Processing  **NO_DATA**    Congé
# 14              6 - Visual computing  **NO_DATA**  Présent
# 15              6 - Visual computing  **NO_DATA**  Présent
# 16   4 - Networks and Communications  **NO_DATA**  Présent
# 17                  7 - Biocomputing  **NO_DATA**    Congé
# 18              6 - Visual computing  **NO_DATA**  Présent
# 19              6 - Visual computing  **NO_DATA**  Présent
# 20              6 - Visual computing  **NO_DATA**  Présent
# 21              6 - Visual computing  **NO_DATA**    Congé
# 22              6 - Visual computing  **NO_DATA**  Présent
# 23              6 - Visual computing  **NO_DATA**  Présent
# 24   4 - Networks and Communications  **NO_DATA**  Présent
# 25              6 - Visual computing  **NO_DATA**  Présent
# 26              6 - Visual computing  **NO_DATA**  Présent
# 27              6 - Visual computing  **NO_DATA**  Présent
# 28              6 - Visual computing  **NO_DATA**    Congé
# 29              6 - Visual computing  **NO_DATA**  Présent
# ..                               ...          ...      ...
# 89              6 - Visual computing  **NO_DATA**  Présent
# 90              6 - Visual computing  **NO_DATA**  Présent
# 91              6 - Visual computing  **NO_DATA**  Présent
# 92              6 - Visual computing  **NO_DATA**  Présent
# 93              6 - Visual computing  **NO_DATA**  Présent
# 94              6 - Visual computing  **NO_DATA**    Congé
# 95                       **NO_DATA**  **NO_DATA**  Présent
# 96              6 - Visual computing  **NO_DATA**    Congé
# 97              6 - Visual computing  **NO_DATA**  Présent
# 98                       **NO_DATA**  **NO_DATA**  Présent
# 99              6 - Visual computing  **NO_DATA**    Congé
# 100                 7 - Biocomputing  **NO_DATA**  Présent
# 101             6 - Visual computing  **NO_DATA**  Présent
# 102             6 - Visual computing  **NO_DATA**  Présent
# 103                 7 - Biocomputing  **NO_DATA**  Présent
# 104                      **NO_DATA**  **NO_DATA**    Congé
# 105             6 - Visual computing  **NO_DATA**  Présent
# 106             6 - Visual computing  **NO_DATA**  Présent
# 107             6 - Visual computing  **NO_DATA**  Présent
# 108             6 - Visual computing  **NO_DATA**    Congé
# 109                      **NO_DATA**  **NO_DATA**  Présent
# 110             6 - Visual computing  **NO_DATA**  Présent
# 111             6 - Visual computing  **NO_DATA**    Congé
# 112             6 - Visual computing  **NO_DATA**  Présent
# 113             6 - Visual computing  **NO_DATA**    Congé
# 114             6 - Visual computing  **NO_DATA**  Présent
# 115                      **NO_DATA**  **NO_DATA**  Présent
# 116             6 - Visual computing  **NO_DATA**  Présent
# 117             6 - Visual computing  **NO_DATA**  Présent
# 118                      **NO_DATA**  **NO_DATA**  Présent
#
#            Type Echange                                      Ecole Echange  \
# 0               Erasmus                              University of Bristol
# 1               Erasmus                               Linköping University
# 2           **NO_DATA**                                        **NO_DATA**
# 3           **NO_DATA**                                        **NO_DATA**
# 4             Bilatéral                  University of Washington, Seattle
# 5               Erasmus  Norwegian University of Science and Technology...
# 6           **NO_DATA**                                        **NO_DATA**
# 7           **NO_DATA**                                        **NO_DATA**
# 8           **NO_DATA**                                        **NO_DATA**
# 9           **NO_DATA**                                        **NO_DATA**
# 10          **NO_DATA**                                        **NO_DATA**
# 11          **NO_DATA**                                        **NO_DATA**
# 12   Mobilité en Suisse        Eidgenössische Technische Hochschule Zürich
# 13            Bilatéral           Georgia Institute of Technology, Atlanta
# 14          **NO_DATA**                                        **NO_DATA**
# 15          **NO_DATA**                                        **NO_DATA**
# 16          **NO_DATA**                                        **NO_DATA**
# 17   Mobilité en Suisse        Eidgenössische Technische Hochschule Zürich
# 18          **NO_DATA**                                        **NO_DATA**
# 19          **NO_DATA**                                        **NO_DATA**
# 20          **NO_DATA**                                        **NO_DATA**
# 21            Bilatéral                Johns Hopkins University, Baltimore
# 22          **NO_DATA**                                        **NO_DATA**
# 23          **NO_DATA**                                        **NO_DATA**
# 24          **NO_DATA**                                        **NO_DATA**
# 25          **NO_DATA**                                        **NO_DATA**
# 26          **NO_DATA**                                        **NO_DATA**
# 27          **NO_DATA**                                        **NO_DATA**
# 28              Erasmus                   Ecole Normale Supérieure de Lyon
# 29          **NO_DATA**                                        **NO_DATA**
# ..                  ...                                                ...
# 89          **NO_DATA**                                        **NO_DATA**
# 90          **NO_DATA**                                        **NO_DATA**
# 91          **NO_DATA**                                        **NO_DATA**
# 92          **NO_DATA**                                        **NO_DATA**
# 93          **NO_DATA**                                        **NO_DATA**
# 94            Bilatéral              Carnegie Mellon University Pittsburgh
# 95          **NO_DATA**                                        **NO_DATA**
# 96              Erasmus                                   Aalto University
# 97          **NO_DATA**                                        **NO_DATA**
# 98          **NO_DATA**                                        **NO_DATA**
# 99              Erasmus     Royal Institute of Technology, (KTH) Stockholm
# 100         **NO_DATA**                                        **NO_DATA**
# 101         **NO_DATA**                                        **NO_DATA**
# 102         **NO_DATA**                                        **NO_DATA**
# 103         **NO_DATA**                                        **NO_DATA**
# 104         **NO_DATA**                                        **NO_DATA**
# 105         **NO_DATA**                                        **NO_DATA**
# 106         **NO_DATA**                                        **NO_DATA**
# 107         **NO_DATA**                                        **NO_DATA**
# 108             Erasmus     Royal Institute of Technology, (KTH) Stockholm
# 109         **NO_DATA**                                        **NO_DATA**
# 110         **NO_DATA**                                        **NO_DATA**
# 111           Bilatéral                   National University of Singapore
# 112         **NO_DATA**                                        **NO_DATA**
# 113             Erasmus                             Universidad de Granada
# 114         **NO_DATA**                                        **NO_DATA**
# 115         **NO_DATA**                                        **NO_DATA**
# 116         **NO_DATA**                                        **NO_DATA**
# 117         **NO_DATA**                                        **NO_DATA**
# 118         **NO_DATA**                                        **NO_DATA**
#
#     No Sciper
# 0      246671
# 1      251759
# 2      248575
# 3      215576
# 4      249498
# 5      234551
# 6      249694
# 7      236818
# 8      219665
# 9      208714
# 10     246184
# 11     249733
# 12     247328
# 13     251758
# 14     247321
# 15     214939
# 16     234716
# 17     250300
# 18     237971
# 19     234523
# 20     247537
# 21     249954
# 22     246310
# 23     244060
# 24     236079
# 25     235493
# 26     235400
# 27     247015
# 28     249996
# 29     246076
# ..        ...
# 89     247917
# 90     247650
# 91     250976
# 92     251034
# 93     238150
# 94     247233
# 95     216801
# 96     225452
# 97     225691
# 98     228149
# 99     250362
# 100    239759
# 101    234868
# 102    249936
# 103    232155
# 104    235935
# 105    236092
# 106    232157
# 107    235786
# 108    247680
# 109    234584
# 110    235116
# 111    246532
# 112    250396
# 113    247891
# 114    250410
# 115    212826
# 116    250419
# 117    237151
# 118    226652
#
# [119 rows x 11 columns]
