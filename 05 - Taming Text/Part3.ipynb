# %%
import os

# Pandas
import pandas as pd

#Matplot
import matplotlib.pyplot as plt

# WordCloud (https://github.com/amueller/word_cloud)
from wordcloud import WordCloud

#NTK
import nltk
from nltk import word_tokenize

# %% [markdown]
# ## Part 3.
#
# > Using the models.ldamodel module from the gensim library, run topic modeling over the corpus. Explore different numbers of topics (varying from 5 to 50), and settle for the parameter which returns topics that you consider to be meaningful at first sight

# %%
import gensim
from gensim.models.ldamodel import LdaModel

from gensim.corpora.dictionary import Dictionary

from nltk.corpus import stopwords
from nltk.tokenize import RegexpTokenizer
import re
# Out:
# /home/danny/anaconda3/lib/python3.5/site-packages/gensim/utils.py:1015: UserWarning: Pattern library is not installed, lemmatization won't be available.
#   warnings.warn("Pattern library is not installed, lemmatization won't be available.")

# %%
# EXACTLY THE SAME CODE AS IN PART I

data_path = "hillary-clinton-emails/"
emails  = pd.read_csv(data_path+"Emails.csv",index_col=0)


cleanBodyText = emails.ExtractedBodyText.dropna()
cleanSubject = emails.ExtractedSubject.dropna()
emailBodyText = "".join(cleanBodyText.astype(str))
emailSubject = "".join(cleanSubject.astype(str))
emailRawText = emailBodyText + emailSubject
tokenizer = RegexpTokenizer(r'\w+')
tokens2 = tokenizer.tokenize(emailRawText)
words_after_tokenization = tokens2

for i,words in enumerate(words_after_tokenization):
    if "US" == words:
        words_after_tokenization[i] = "u.s."
        
words_lower = [word.lower() for word in words_after_tokenization]
stop_words = set(stopwords.words('english'))
stop_words.update(['.', ',', '"', "'", '?', '!', ':', ';', '(', ')', '[', ']', '{', '}'])
words_no_more_stop = [word for word in words_lower if word not in stop_words]

# %%
data = words_no_more_stop

dico = Dictionary([data])

# %%
corpus = [dico.doc2bow(text) for text in [data]]

# %%
def clean_lda_string (string):
    return " ".join(re.split("[^a-zA-Z]*", string))

# %%
file = open("LDA.txt", "w")

# %%
for nbr_topics in range(5,51,5):
    s = "======================="+str(nbr_topics)+"==============================="
    print(s)
    file.write(s + '\n')
    
    lda = LdaModel(corpus, num_topics=nbr_topics, id2word=dico)
    for i in range(0, lda.num_topics):
        string = lda.print_topic(i)
        topic = clean_lda_string(string)
        print(topic)
        file.write(topic + '\n')

    file.write("\n\n\n")
        
file.close()
# Out:
# =======================5===============================
# /home/danny/anaconda3/lib/python3.5/re.py:203: FutureWarning: split() requires a non-empty pattern match.
#   return _compile(pattern, flags).split(string, maxsplit)
#  state pm call secretary president obama office u would also
#  pm state would call one said secretary u obama
#  state pm would secretary u office call obama said
#  state pm would u said secretary obama new time
#  state pm secretary would one u president new obama call
# =======================10===============================
#  state pm secretary would obama u new call said
#  state pm secretary would call said one new also
#  state pm would one new call president time w
#  state said pm would u obama new call president
#  state pm secretary said u obama call office would also
#  pm state u would secretary one president obama
#  state pm u would secretary president obama call new
