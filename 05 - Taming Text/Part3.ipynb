# %%
import os
# Pandas
import pandas as pd
#NTK
import nltk
from nltk import word_tokenize

# %% [markdown]
# ## Part 3.
#
# > Using the models.ldamodel module from the gensim library, run topic modeling over the corpus. Explore different numbers of topics (varying from 5 to 50), and settle for the parameter which returns topics that you consider to be meaningful at first sight

# %%
import gensim
from gensim.models.ldamodel import LdaModel
from gensim.corpora.dictionary import Dictionary

from nltk.corpus import stopwords
from nltk.tokenize import RegexpTokenizer

import re
# Out:
# /home/danny/anaconda3/lib/python3.5/site-packages/gensim/utils.py:1015: UserWarning: Pattern library is not installed, lemmatization won't be available.
#   warnings.warn("Pattern library is not installed, lemmatization won't be available.")

# %% [markdown]
# We will perform the same data preprocessing steps as in part I:
#
# - Tokenization with *RegexpTokenizer(r'\w+')
# - Stopwords removal
# - Punctuation removal

# %%
# SAME PREPROCESSING AS IN STEP I

data_path = "hillary-clinton-emails/"
emails  = pd.read_csv(data_path+"Emails.csv",index_col=0)

# Email Body
cleanBodyText = emails.ExtractedBodyText.dropna()
emailBodyText = ["".join(x) for x in cleanBodyText]

# Email Subject
cleanSubject = emails.ExtractedSubject.dropna()
emailSubject = ["".join(x) for x in cleanSubject]

# Data = Body + Subject
emailRawText = emailBodyText + emailSubject

# Tokens + Stop words
tokenizer = RegexpTokenizer(r'\w+')
stop_words = set(stopwords.words('english'))
stop_words.update(['.', ',', '"', "'", '?', '!', ':', ';', '(', ')', '[', ']', '{', '}'])

def stepI_preprocessing(data):
    token = tokenizer.tokenize(str(data))
    lower = [word.lower() for word in token]
    words_no_stop = [w for w in lower if w not in stop_words]
    
    return words_no_stop

# Final preprocessing
words_clean = [stepI_preprocessing(x) for x in emailRawText]

# %% [markdown]
# We start by computing two datas, *dico* and *corpus*, needed by the gensim library.

# %%
dico = Dictionary(words_clean)
corpus = [dico.doc2bow(text) for text in words_clean]

# %%
def clean_lda_string (string):
    """
        Clean the lda topic string. Only keeps the alphanumerical characters.
    """
    return " ".join(re.split("[^a-zA-Z]*", string))

# %% [markdown]
# ### Now we compute the *LdaModel*. There is no precise way to choose the best number of topics to search for. Therefore, we try several numbers of topics, from 5 to 50 (step of 5).

# %%
for nbr_topics in range(5,51,5):
    s = "======================="+str(nbr_topics)+"==============================="
    print(s)
    
    lda = LdaModel(corpus, num_topics=nbr_topics, id2word=dico)
    for i in range(0, lda.num_topics):
        string = lda.print_topic(i)
        topic = clean_lda_string(string)
        print(topic)
    
    print()
# Out:
# =======================5===============================
# /home/danny/anaconda3/lib/python3.5/re.py:203: FutureWarning: split() requires a non-empty pattern match.
#   return _compile(pattern, flags).split(string, maxsplit)
#  obama new u one israel said president would state american
#  pm call secretary office w meeting
#  fw h sid reuters ap schedule state update tomorrow
#  haiti sid would h health memo care bill new
#  call fyi speech talk u list new qddr today one
#
# =======================10===============================
#  said obama new us mr afghanistan one would iran party
#  call ni fw sheet haiti tomorrow calls state
#  reuters ashton afghan fw state talks security sudan gaza obama
#  fw h sid schedule ap update state mini
#  would one israel new u netanyahu president also china government
#  pm office secretary call w meeting state
#  call talk tomorrow list today tonight followup confirmed email jim
#  call speech get statement good draft u see report want
#  fyi haiti care health would new happy work senate stone
#  u calls israel state israeli rights human us report statement
#
# =======================15===============================
#  tomorrow talk today call happy u get mubarak trip update
#  obama new said rights one president mr people political human
#  pm office secretary meeting w
#  call schedule list update confirmed calls ops sheet holbrooke email
#  talks israel blair palestinians un w see would speech settlement
#  fw h sid state speech schedule gov haiti
#  qddr percent poll election sbu mail
#  u us pakistan would afghanistan new women iran states united
#  reuters ap iran says question clinton obama kabul talks mother
#  party said new one would obama two health time year
#  statement ok followup fw state sullivan j sunday bill
#  fyi draft ashton pls maggie letter prayer print update thx
#  u state secretary still back house birthday kerry call think
#  israeli report state netanyahu obama palestinian gaza israel new president
#  ireland good foreign article david president personal report northern would
#
# =======================20===============================
#  u state obama afghanistan people president clinton health two house
#  speech question taliban fw kerry op ed internet gelb state
#  thanks notes state npr kurt espinosa mexican urgence tftp remind
#  senate info rolling interview mack cloture checking house bill passage
#  calls call back work get good trip start u us
#  call list vote percent today see
#  schedule call mini w email followup confirmed ops state
#  israel israeli peace settlement palestinian palestinians ok ireland arab settlements
#  holbrooke eikenberry thank netanyahu talk stone bloomberg dan cuba breakfast
#  ashton water expo call birthday proposed abbas state climate india
#  women un pakistan u haiti aid new international security afghan
#  fw fyi ap update call qddr haiti hrc sheet
#  b honduras today press release see part dialogue via h
#  pm secretary office meeting w
#  sid h statement memo rights blair human uk new sudan
#  fw reuters h state gov talks sid pm ni
#  yes like know mother would said news still time reid
#  tomorrow report talk call tonight mubarak draft letter anything know
#  party talks eu would labour news fa good iran also
#  obama said new would american one iran foreign mr president
#
# =======================25===============================
#  iran netanyahu right leader foreign party president would cameron american
#  obama house president press white state strategic dialogue washington
#  party sudan good labour call language budget would one robinson
#  start statement senate reid would people pakistan legislation one next
#  fw fyi update pm cheryl state secretary haiti
#  u israel israeli state rights human peace united states security
#  talks test sign e rok names goldman tried case would
#  pm office secretary meeting w
#  netanyahu call foreign pak affairs cuba ds development u psd
#  reuters fw thanks b release huma gov proposed h state
#  like urgent news boehner corker good new would dies idea
#  call ok followup asking mazen abu mashabane lavrov points east
#  women us new internet g russia bibi could kyrgyzstan u
#  schedule mini statement state friday gov thank monday
#  haiti ed un op haitian political qddr campaign au
#  bill care health mother would video reform happy u day
#  david aipac kerry john beck clinton tv president lugar missing
#  ireland bomb sbu state personal message nyt mail u northern
#  breakfast pls print prayer npr syria urgence tftp pentagon funeral
#  qddr iran afghan said question afghanistan taliban trip kabul would
#  call speech list confirmed ashton ni update sheet new article
#  one new stone year water called says wjc book paper
#  sid h ap fw memo blair latest tony uk new
#  percent poll election london obama eu party
#  tomorrow talk call today calls draft w get happy back
#
# =======================30===============================
#  update mubarak secretary pls call state note mail please letter
#  yet maggie left alexander new isabelle sure tomorrow talked max
#  haiti info book kyrgyzstan great company au egypt status bibi
#  obama iran president one health would policy new care american
#  un king kristof wsj india remind confirmations urgence wikileaks
#  list call calls today ed op mtg nato thanks dinner
#  state h press thank com hrod clintonemail gov sid cable
#  sid iran happy china h day bomb mother new mideast
#  pm office secretary meeting w
#  calls thank mubarak kerry lugar espinosa mexican election
#  call list start haiti request tonight w senate points yet
#  fw speech update letter iran pls b release hrc see
#  checking email sean foreign bangladesh per friend spending pm via
#  settlement freeze eu palestinians israel oas jerusalem wilson baby israeli
#  clinton state armenia u fox karl reminder dorothy greece boss
#
# =======================50===============================
#  un abu mazen prayer company missile oas haiti hikers earthquake
#  senate fax reid kerry state dc bob start john direct
#  thank start note doha faxed tried questions attached mod version
#  nato germany nides london uk robinson guinea reminder thing important
#  vote poll favorable rep voters
#  party one northern iraq ireland obama president would mr american
#  sid h memo ni pls print statement brava follow issue
#  palestinians honduras steinberg bomb w mitchell mideast notes would schedule
#  pm office secretary meeting w
#  followup sudan letter budget mother affairs bloomberg kristof haiti etc
#  netanyahu call fm saudi mashabane percent king cuba obama
#  recognition eta state freeman theme vilsack dorothy assessing subject u
#  rights human turkey u afghanistan possible posner petraeus armenia general
#  calls expo sec corker harry afp max krishna said corporations
#  qddr secretary breakfast clinton gates week discuss would time usglc
#  taliban birthday federal clinton secretary afghanistan paris strikes office state
#  call confirmed sheet press dinner breakthrough kabul
#  work mexico potential done gender panel development back global summit
#  us e policy new world even obama women washington one
#  stone book personal would one yes think tax obama greek
#  haiti ed op post article missing feedback news asked au
#  blair secure holbrooke talk hours cabinet ellen statement tony sid
#  report draft news today jim call yet anything pak good
#  fw ap update state pm gov h
#  fyi israeli statement israel palestinian gaza fw h sid gelb
#  beck palau rok sri lanka us records dave passing freed
#  mail email e travel please state sbu address ds
#  iran question per irish mepp bill usa japan oil deal
#  eu npr us statement state nita lowey said deadline cable
#  wjc hrc mclarty onward gore mccain ideal rock troika speeches
#  article readout economist karl cables play couple sends district business
#  speech mubarak fwd call request bravo mtg available draft word
#  pakistan russia aid kyrgyzstan india donors humanitarian idea ig outlook
#  talks lavrov quartet bibi buy lunch goodwill sorry lebanon polls
#  boehner haiti party water would one said people still bill
#  strategic u state doc department dialogue planning proposal anne diplomacy
#  health care obama house sen senate white said reform republicans
#  urgent miliband gay urgence kudos anti hillary resign status nazi
#  call list ashton happy latest b tonight h thru release
#  nyt deal internet freedom new china bank rice treaty migrants
#  reuters afghan shuttle info ops trying paper hold shaun reach
#  tomorrow talk u asking today call tonite points r text
#  sign media dollars billions kill u tftp pledge china pj
#  tea undeliverable biden hear fire waiting militants rocket casualties images
#  schedule mini trip friday maggie monday call email fa
#  state clinton american nuclear new security u mcchrystal said north
#  ok israel peace talks east middle karzai richard aipac hamas
#  views bbc send libya negotiating sid proposing editorial addresses quote
#  david proposed labour holbrooke eikenberry times plane u change
#  election new climate said president one would obama may right

# %% [markdown]
# As we can see, the more number of topics we have, to more diverse topics the algorithm outputs.
#
# With *num_topics=50* for example, we have topics that are too many detailed.
#
# With *num_topics=5* there is topics about meetings, obama, afganhistan, and israel.
#
# We think that with a value of num_topics around 15 was a good choice. Therefor, there is enough topics and not too much detailed. It represents well the politics subject that Hillary Clinton dealed with while she was secretary of state: Some U.S. politics, international subject, like Israel, Middle East, and Haiti, but also a lot of meetings and organisational issues.
